# %%
#한글 폰트 사용 : colab , 런타임 다시 시작 하기
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.title('한글')
plt.show()

# %% [markdown]
# ### 데이터 가져오기

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/drive/MyDrive/2022_기초컴퓨터프로그래밍/기말고사/mbc.csv')
df.head()
# Out:
#    순위                                    기사제목  댓글수  구분
# 0   1     이재명 이준석 겨냥 민주당 대표가 성 상납 받았으면 당 해체됐다  668  기사
# 1   2         특혜 의혹 윤 대통령 처가 회사 양평군에 개발부담금 완납  322  기사
# 2   3          이상민 한동훈 임명 밀어붙이면 윤 대통령이 협치 깬 것  297  기사
# 3   4  권성동 윤재순 일방적 단죄는 적절치 않아‥본인 입장 듣고 여론 살펴야  171  기사
# 4   5                  북한 우리 측 지원 의사에 이틀째 무응답  158  기사

# %% [markdown]
# ### matplotlib.pyplot 모듈 기본 그래프 그리기
# + 기본그래프 그리기
#   + plot() 함수는 리스트의 값들이 y 값들이라고 가정하고, x 값 [0, 1, 2, 3]을 자동
#   + show() 함수는 그래프를 화면에 나타나도록함
# + 그래프 제목 추가
#    + title() 함수 : 그래프의 제목 설정
#    + xlabel() 함수: 그래프의 x축에 대한 제목을 표시
#    + ylabel() 함수: 그래프의 y축에 대한 제목을 표시
# + 선 모양 정하기
#   + **색상**
#   - b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#   + **마커**
#   - o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)
#   + **선스타일**
#   - \-(solid line), --(dashed line ), -. (dash-dot line), : (dotted line )
# + 크기 지정하기
#  - figure() :  figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)
# + x축 눈금지정하기
#  + xticks() :  X축에 눈금을 표시
#   + labels 파라미터를 사용하면 눈금 레이블을 문자열의 형태로 지정
#   + rotation 파라미터를 사용하면 눈금 레이블 회전

# %%
df.plot()
plt.show()

# %%
# plt.figure(figsize=(10,6))
plt.title('댓글현황')
plt.plot(df['기사제목'],df['댓글수'],'go--')
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(10,6))
plt.bar(df['기사제목'],df['댓글수'])
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(10,6))
plt.plot(df['기사제목'],df['댓글수'],'go--',label = "꺽은선 그래프")
plt.bar(df['기사제목'],df['댓글수'],label="막대그래프")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### Pandas  plot()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      20 non-null     int64
#  1   기사제목    20 non-null     object
#  2   댓글수     20 non-null     int64
#  3   구분      20 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 768.0+ bytes

# %%
df.columns
# Out:
# Index(['순위', '기사제목', '댓글수', '구분'], dtype='object')

# %% [markdown]
# ## seaborn
# * matplotlib의 상위 호환 데이터 시각화를 위한 라이브러리
# * 데이터프레임으로 다양한 통계 지표를 낼 수 있는 시각화 차트를 제공하기 때문에 데이터 분석에 활발히 사용되고 있는 라이브러리

# %%
import seaborn as sns

# %%
# plt.figure(figsize=(10,6))
sns.barplot(x='구분', y='댓글수' ,data = df)
plt.show()

# %%
# plt.figure(figsize=(10,6))
sns.barplot(x='기사제목', y='댓글수',data = df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='댓글수',y='기사제목',data=df)
#label 숨기기 
plt.xlabel("")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### barplot
# + 댓글 수가 평균 댓글수보다 많은 기사

# %%
df2 = df[df['댓글수']>df['댓글수'].mean()]
df2
# Out:
#    순위                                    기사제목  댓글수  구분
# 0   1     이재명 이준석 겨냥 민주당 대표가 성 상납 받았으면 당 해체됐다  668  기사
# 1   2         특혜 의혹 윤 대통령 처가 회사 양평군에 개발부담금 완납  322  기사
# 2   3          이상민 한동훈 임명 밀어붙이면 윤 대통령이 협치 깬 것  297  기사
# 3   4  권성동 윤재순 일방적 단죄는 적절치 않아‥본인 입장 듣고 여론 살펴야  171  기사
# 4   5                  북한 우리 측 지원 의사에 이틀째 무응답  158  기사
# 5   6   윤 대통령 한동훈 오늘 임명? 검토해보겠다‥윤재순 질문엔 좋은 하루  137  기사

# %%
sns.barplot(x='댓글수', y='기사제목',data = df2)
#label 숨기기
plt.xlabel("")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Countplot
# * 구분별 기사수

# %%
df['구분'].value_counts()
# Out:
# 기사     10
# 동영상    10
# Name: 구분, dtype: int64

# %%
sns.countplot(x='구분',data=df)
plt.show()

# %%
sns.countplot(y='구분',data=df)
plt.show()

# %%
#댓글이 평균 댓글보다 많으면 1, 적으면 0
data = []
for i in range(0,len(df)):
  number = df.iloc[i]['댓글수']
  if(number > df['댓글수'].mean()):
    data.append("평균보다 댓글이 많은 기사")
  else:
    data.append("평균보다 댓글이 적은 기사")

df['평균값'] = data

df
# Out:
#     순위                                            기사제목  댓글수   구분  \
# 0    1             이재명 이준석 겨냥 민주당 대표가 성 상납 받았으면 당 해체됐다  668   기사
# 1    2                 특혜 의혹 윤 대통령 처가 회사 양평군에 개발부담금 완납  322   기사
# 2    3                  이상민 한동훈 임명 밀어붙이면 윤 대통령이 협치 깬 것  297   기사
# 3    4          권성동 윤재순 일방적 단죄는 적절치 않아‥본인 입장 듣고 여론 살펴야  171   기사
# 4    5                          북한 우리 측 지원 의사에 이틀째 무응답  158   기사
# 5    6           윤 대통령 한동훈 오늘 임명? 검토해보겠다‥윤재순 질문엔 좋은 하루  137   기사
# 6    7                   민주 용산 졸속이전으로 도미노식 피해‥제왕적 일방통행   73   기사
# 7    8                           한동훈 임명 강행 기류‥여야 대치 격화   47  동영상
# 8    9                     탈모인의 성지 가봤더니‥대리 처방에 택배 배달까지   41  동영상
# 9   10                     검찰 윤석열 검찰총장 당시 피고발 사건 6건 각하   24   기사
# 10  11                          비트코인 팔아 가격 방어 시도‥보상 논의   23  동영상
# 11  12                     다시 번지는 미국 코로나‥북동부 신규 확진자 급증   23  동영상
# 12  13              김용태 최고 대통령실 윤재순 관련 사과하고 거취 조속 결정해야   16   기사
# 13  14                      임대차 3법 시행 2년‥전월세 대폭 인상 막았다   16  동영상
# 14  15  [World Now_영상] 마지막 햄버거 먹으러‥ 맥도날드 32년만에 러시아서 철수   15  동영상
# 15  16                      롯데월드 놀이기구 운행 중 멈춰‥승객 8명 대피   11   기사
# 16  17                           던지고 꼬집고‥상습 학대 공포의 유치원   10  동영상
# 17  18                [방송3사 여론조사] 경기 초접전‥서울·인천 국민의힘 우세   10  동영상
# 18  19                        정의당도 성추문‥지도부 은폐 vs 사실 아냐    8  동영상
# 19  20                            도와주겠다 통지문 발송 시도‥묵묵부답    8  동영상
#
#                평균값
# 0   평균보다 댓글이 많은 기사
# 1   평균보다 댓글이 많은 기사
# 2   평균보다 댓글이 많은 기사
# 3   평균보다 댓글이 많은 기사
# 4   평균보다 댓글이 많은 기사
# 5   평균보다 댓글이 많은 기사
# 6   평균보다 댓글이 적은 기사
# 7   평균보다 댓글이 적은 기사
# 8   평균보다 댓글이 적은 기사
# 9   평균보다 댓글이 적은 기사
# 10  평균보다 댓글이 적은 기사
# 11  평균보다 댓글이 적은 기사
# 12  평균보다 댓글이 적은 기사
# 13  평균보다 댓글이 적은 기사
# 14  평균보다 댓글이 적은 기사
# 15  평균보다 댓글이 적은 기사
# 16  평균보다 댓글이 적은 기사
# 17  평균보다 댓글이 적은 기사
# 18  평균보다 댓글이 적은 기사
# 19  평균보다 댓글이 적은 기사

# %%
sns.countplot(x='평균값',data = df)
plt.show()

# %% [markdown]
# ### displot
# * matplotlib의 hist 그래프와 kdeplot을 통합한 그래프

# %%
# plt.figure(figsize=(10,7)) 
sns.distplot(df['댓글수'], kde = True)
plt.show()

# %% [markdown]
# ### heatmap
# * 다양한 값을 갖는 숫자 데이터를 열분포 형태와 같이 색상을 이용해서 시각화

# %%
plt.rcParams['axes.unicode_minus'] = False  
# plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True)
plt.show()
